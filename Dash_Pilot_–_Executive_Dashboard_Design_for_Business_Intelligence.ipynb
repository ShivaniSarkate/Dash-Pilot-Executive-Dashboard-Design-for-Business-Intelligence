# %% [markdown]
# **Project Title : DashPilot - Executive Dashboard Design for Business Intelligence**

# %% [markdown]
# **Objective** : Design a business intelligence dashboard that visualizes key performance indicators (KPIs) for executive decision-making.

# %% [markdown]
# **Business Context** : Executives need fast, clear access to performance metrics. Dashboards help monitor trends, spot risks, and guide strategic decisions.

# %% [markdown]
# **Workflow Overview** :
# - Simulate business performance data
# - Select relevant KPIs
# - Design dashboard layout
# - Visualize metrics with charts
# - Recommend stakeholder actions

# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Simulate KPI data
np.random.seed(42)
months = pd.date_range(start='2023-01-01', periods=12, freq='M')
df = pd.DataFrame({
    'Month': months,
    'Revenue': np.random.normal(500000, 50000, 12),
    'CustomerCount': np.random.poisson(1200, 12),
    'ConversionRate': np.random.uniform(0.03, 0.07, 12),
    'ChurnRate': np.random.uniform(0.02, 0.05, 12)
})

# Step 3: Plot dashboard-style charts
fig, axs = plt.subplots(2, 2, figsize=(12,8))
sns.lineplot(data=df, x='Month', y='Revenue', ax=axs[0,0]).set_title('Monthly Revenue')
sns.lineplot(data=df, x='Month', y='CustomerCount', ax=axs[0,1]).set_title('Customer Count')
sns.lineplot(data=df, x='Month', y='ConversionRate', ax=axs[1,0]).set_title('Conversion Rate')
sns.lineplot(data=df, x='Month', y='ChurnRate', ax=axs[1,1]).set_title('Churn Rate')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-375765340.py:9: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   months = pd.date_range(start='2023-01-01', periods=12, freq='M')

# %% [markdown]
# **Executive Summary** :
# - **Revenue Trend**: Stable with slight growth
# - **Customer Growth**: Consistent acquisition
# - **Conversion Rate**: Peaked in Q2, dip in Q4
# - **Churn Rate**: Rising slightly—needs attention
# - **Recommendation**:
#   - Investigate Q4 conversion dip
#   - Launch retention initiatives to reduce churn
#   - Use dashboard for monthly executive reviews
# - **Impact**: Dashboards improve visibility, speed up decisions, and align *teams*
